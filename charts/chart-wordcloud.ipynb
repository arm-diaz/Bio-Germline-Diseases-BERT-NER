# %%
import pandas as pd
from wordcloud import WordCloud
from collections import Counter
import matplotlib.pyplot as plt

# %%
gene_df = pd.read_csv("../results/ner_disambiguated_genes.csv")
diseases_df = pd.read_csv("../results/ner_disambiguated_diseases.csv")

# %%
gene_ner_words = Counter(gene_df[gene_df["word"].notnull()]["word"])
gene_ner_dis_words = Counter(gene_df[gene_df["gene"].notnull()]["gene"])

# %%
diseases_ner_words = Counter(diseases_df[diseases_df["word"].notnull()]["word"])
diseases_ner_dis_words = Counter(diseases_df[diseases_df["diseases"].notnull()]["diseases"])

# %%
wordcloud = WordCloud(background_color="#e2e1eb", max_words=100).generate_from_frequencies(gene_ner_words)

#plt.figure(figsize=(15,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# store to file
wordcloud.to_file("../images/wordCloudGene.png")

# %%
wordcloud = WordCloud(background_color="#e2e1eb", max_words=100).generate_from_frequencies(gene_ner_dis_words)

#plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# store to file
wordcloud.to_file("../images/wordCloudDisambiguatedGene.png")

# %%
wordcloud = WordCloud(background_color="#e2e1eb", max_words=100).generate_from_frequencies(diseases_ner_words)

#plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# store to file
wordcloud.to_file("../images/wordCloudDisease.png")

# %%
wordcloud = WordCloud(background_color="#e2e1eb", max_words=100).generate_from_frequencies(diseases_ner_dis_words)

#plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# store to file
wordcloud.to_file("../images/wordCloudDisambiguatedDisease.png")
